# %% [markdown]
# <a href="https://colab.research.google.com/github/mjbutrim/automatedarea/blob/main/apply_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%
# %%capture
# !pip install alphashape
# !pip install skan
# !pip install -U gdown
# %%

# Download functions, a test image, and the trained model from github and google drive.
# !wget https://raw.githubusercontent.com/mjbutrim/automatedarea/main/functions.py
# !wget https://raw.githubusercontent.com/mjbutrim/automatedarea/main/LaPorte%20P208%20Petrea%20rotunda%20947.JPG
# !gdown 1xg2csnX-3LhNyY_GDg9n2L8CiMlThD-z

import functions as fossilarea
model_path = '/content/trained_model_5class.tar'
model, device = fossilarea.load_model(model_path)

# %%
# Set parameters for segmentation and/or area reconstruction
image_path = "/content/LaPorte P208 Petrea rotunda 947.JPG"
conversion = 300

# %%
# Segmentation - save and visualize can be set to True or False
picture = fossilarea.predict_and_visualize(image_path, model, device, save = False, visualize = True)

# %%
# Area reconstruction - returns [0] fragment area (Plot C); [1] reconstructed area (Plot E); [2] median rectangle secondary vein density; [3] a list of all rectangles and their densities
reconstructed_area = fossilarea.reconstruct_area(image_path, model, device, conversion, plot = True, save = False)
print(f"Fragment area = {reconstructed_area[0]}; Reconstructed area = {reconstructed_area[1]}")
# Out:
# Fragment area = 75.39518475; Reconstructed area = 65.39610777625926
